# %%
# !pip install google-generativeai llama-index llama-index-llms-gemini
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 60.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 49.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 82.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 45.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.4/142.4 kB 10.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.9.1
# ...

# %%
import os
os.kill(os.getpid(), 9)

# %%
# !pip install google-generativeai llama-index llama-index-llms-gemini

# %%
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyCVlTprGarncZ7rbvSVeeXdg8a1AXymbmo"

# %%
print("Working ✅")
# Out:
# Working ✅

# %% [markdown]
# ### Using `SimpleDirectoryReader` to Load Documents
#
# `SimpleDirectoryReader` from `llama_index.core` is used to load data from a specified directory. It automatically identifies and reads various file types, converting them into `Document` objects that can be processed by LlamaIndex.

# %%
from llama_index.core import SimpleDirectoryReader

# Load documents from the 'data' directory
documents = SimpleDirectoryReader("data").load_data()

# Display the loaded documents
print(documents)
# Out:
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# ...

# %%
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyCVlTprGarncZ7rbvSVeeXdg8a1AXymbmo"

# %%
import google.generativeai as genai

# Configure API key (using the one already set in the previous cell)
genai.configure(api_key="AIzaSyCVlTprGarncZ7rbvSVeeXdg8a1AXymbmo")

for m in genai.list_models():
  if "generateContent" in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# ...

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyCVlTprGarncZ7rbvSVeeXdg8a1AXymbmo")

model = genai.GenerativeModel("gemini-2.5-flash")

response = model.generate_content("Explain Artificial Intelligence in one line")

print(response.text)
# Out:
# Artificial Intelligence is the science of enabling machines to perform tasks that traditionally require human intelligence.

# %%
import os

os.makedirs("data", exist_ok=True)

with open("data/file1.txt", "w") as f:
    f.write("Artificial Intelligence is the simulation of human intelligence.")

with open("data/file2.txt", "w") as f:
    f.write("Machine Learning is a subset of AI.")

# %%
# !ls data
# Out:
# file1.txt  file2.txt

# %%
from llama_index.core import SimpleDirectoryReader

documents = SimpleDirectoryReader("data").load_data()

print(documents)
# Out:
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# ...

# %%
from llama_index.llms.gemini import Gemini

llm = Gemini(
    model="models/gemini-2.5-flash",
    api_key="AIzaSyCVlTprGarncZ7rbvSVeeXdg8a1AXymbmo"
)
# Out:
# /tmp/ipykernel_9769/3196745751.py:3: DeprecationWarning: Call to deprecated class Gemini. (Should use `llama-index-llms-google-genai` instead, using Google's latest unified SDK. See: https://docs.llamaindex.ai/en/stable/examples/llm/google_genai/This package will no longer be supported after version 0.6.2) -- Deprecated since version 0.6.2.
#   llm = Gemini(

# %%
# !pip install llama-index-llms-google-genai

# %%
from llama_index.llms.google_genai import GoogleGenAI

llm = GoogleGenAI(
    model="gemini-2.5-flash",
    api_key="AIzaSyCVlTprGarncZ7rbvSVeeXdg8a1AXymbmo"
)

# %%
from llama_index.core import SimpleDirectoryReader
documents = SimpleDirectoryReader("data").load_data()

# !pip install llama-index-embeddings-huggingface
from llama_index.core import VectorStoreIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# Explicitly set embed_model to a local HuggingFace embedding model
# A common choice is 'BAAI/bge-small-en-v1.5'
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
index = VectorStoreIndex.from_documents(documents, embed_model=embed_model)
# Out:
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# ...
# WARNING: huggingface-hub 1.11.0 does not provide the extra 'inference'
# ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
import nest_asyncio
nest_asyncio.apply()

from llama_index.core import SimpleDirectoryReader
from llama_index.core import VectorStoreIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.google_genai import GoogleGenAI

# Define documents (from cell O-VpK2Zl4Oaz)
documents = SimpleDirectoryReader("data").load_data()

# Define embed_model (from cell O-VpK2Zl4Oaz)
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")

# Define index (from cell O-VpK2Zl4Oaz)
index = VectorStoreIndex.from_documents(documents, embed_model=embed_model)

# Define llm (from cell YjB8CG944GLC)
llm = GoogleGenAI(
    model="gemini-2.5-flash",
    api_key="AIzaSyCVlTprGarncZ7rbvSVeeXdg8a1AXymbmo"
)

# Original code
query_engine = index.as_query_engine(llm=llm)

response = query_engine.query("What is AI and Machine Learning?")

print(response)
# Out:
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: BAAI/bge-small-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Artificial Intelligence is the simulation of human intelligence. Machine Learning is a subset of Artificial Intelligence.

# %%
query_engine = index.as_query_engine(llm=llm)

response = query_engine.query("What is AI and Machine Learning?")

print(response)
# Out:
# Artificial Intelligence is the simulation of human intelligence. Machine Learning is a subset of Artificial Intelligence.
